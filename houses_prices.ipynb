# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('train.csv')

# %%
colunas_sem_dados = df.columns[df.isnull().any()].tolist()

# Imprime as colunas sem dados
print("Colunas sem dados:")
for col in colunas_sem_dados:
    print(col)
# Out:
# Colunas sem dados:
# LotFrontage
# Alley
# MasVnrType
# MasVnrArea
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Electrical
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageQual
# GarageCond
# PoolQC
# Fence
# MiscFeature

# %%
print(df[['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical']].to_string(index=False))
# Out:
#  LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 Electrical
#         65.0   NaN    BrkFace       196.0       Gd       TA           No          GLQ          Unf      SBrkr
#         80.0   NaN       None         0.0       Gd       TA           Gd          ALQ          Unf      SBrkr
#         68.0   NaN    BrkFace       162.0       Gd       TA           Mn          GLQ          Unf      SBrkr
#         60.0   NaN       None         0.0       TA       Gd           No          ALQ          Unf      SBrkr
#         84.0   NaN    BrkFace       350.0       Gd       TA           Av          GLQ          Unf      SBrkr
#         85.0   NaN       None         0.0       Gd       TA           No          GLQ          Unf      SBrkr
#         75.0   NaN      Stone       186.0       Ex       TA           Av          GLQ          Unf      SBrkr
# ...

# %%
print(df[['FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']].to_string(index=False))
# Out:
# FireplaceQu GarageType  GarageYrBlt GarageFinish GarageQual GarageCond PoolQC Fence MiscFeature
#         NaN     Attchd       2003.0          RFn         TA         TA    NaN   NaN         NaN
#          TA     Attchd       1976.0          RFn         TA         TA    NaN   NaN         NaN
#          TA     Attchd       2001.0          RFn         TA         TA    NaN   NaN         NaN
#          Gd     Detchd       1998.0          Unf         TA         TA    NaN   NaN         NaN
#          TA     Attchd       2000.0          RFn         TA         TA    NaN   NaN         NaN
#         NaN     Attchd       1993.0          Unf         TA         TA    NaN MnPrv        Shed
#          Gd     Attchd       2004.0          RFn         TA         TA    NaN   NaN         NaN
#          TA     Attchd       1973.0          RFn         TA         TA    NaN   NaN        Shed
#          TA     Detchd       1931.0          Unf         Fa         TA    NaN   NaN         NaN
# ...

# %%
with open("data_description.txt", "r") as f:
    conteudo = f.read()
    print(conteudo)
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %%
df.GarageYrBlt.describe(percentiles = [0.9, 0.95, 0.99])
# Out:
# count    1379.000000
# mean     1978.506164
# std        24.689725
# min      1900.000000
# 50%      1980.000000
# 90%      2006.000000
# 95%      2007.000000
# 99%      2009.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %%
df[['GarageYrBlt']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# palavra
